# %%
import tweepy
import matplotlib.pyplot as plt
from  textblob import TextBlob 

# all 4 authentication keys to access twitter API
# to connect as OAth handler or jump serever / revers proxy server
consumer_key = "lRaFRWxWqvkfL3zc80bwb9rEV"
consumer_sec = "PQz4srk2my6oE2bhe3TgU0W5jYaRBP6Rp5a379U6BPNV8ruJHd"

# from proxy server we need to connect
access_token = "1490683028775247875-ygvzd2MPE2ZY6UEEDzk5cypGf0mN4v"
access_token_sec = "5PWClRD1gBjc5x8jVDO8ukaelqOfDeNqUZVq1uht8AGvJ"

# connected to jump server of twitter
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)

# now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_token_sec)

# now we can connect to API storge server of twitter
api_connect=tweepy.API(auth)

# now you can search any topic on twitter
tweet_data=api_connect.search('Elon Musk',count=100)

pos=0
neg=0
neu=0

# printing line by line
for tweet in tweet_data:
   #print(tweet.text)
   analysis=TextBlob(tweet.text) # here it will apply NLP\
   print(analysis.sentiment)
   # now checking polarity only
   if analysis.sentiment.polarity > 0:
      print("Positive")
      pos=pos+1
   elif analysis.sentiment.polarity == 0 :
      print("Neutral")
      neu=neu+1
   else :
      print("Negative")
      neg=neg+1
      
# ploting graphs
plt.xlabel("tags")
plt.ylabel("polarity")
#plt.bar(['pos','neg','neu'],[pos,neg,neu])
plt.pie([pos,neg,neu],labels=['pos','neg','neu'],autopct="%1.1f%%")
plt.show()
# Out:
# Sentiment(polarity=0.016666666666666666, subjectivity=0.03333333333333333)
# Positive
# Sentiment(polarity=-0.075, subjectivity=0.7972222222222223)
# Negative
# Sentiment(polarity=0.55, subjectivity=0.55)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.024999999999999994, subjectivity=0.625)
# Positive
# Sentiment(polarity=-0.125, subjectivity=0.125)
# Negative
# Sentiment(polarity=0.25, subjectivity=0.30000000000000004)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.4666666666666667, subjectivity=0.6666666666666667)
# Positive
# Sentiment(polarity=0.05, subjectivity=1.0)
# Positive
# Sentiment(polarity=0.375, subjectivity=0.32499999999999996)
# Positive
# Sentiment(polarity=-0.125, subjectivity=0.30000000000000004)
# Negative
# ...
